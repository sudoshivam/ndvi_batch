# %%
# add 'gdalwheel' dataset to input before running this command 
# !python3 -m pip install ../input/gdalwheel/GDAL-3.1.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl

# %%
import numpy as np
from numpy import nan_to_num, subtract, add, divide, multiply
from osgeo import gdal, gdalconst
import gdal
from gdal import GetDriverByName, Open
from glob import glob
import os

# %%
def ndvi(in_nir_band, in_colour_band, in_rows, in_cols, in_geotransform, out_tiff, data_type=gdal.GDT_Float32):

    """
    Performs an NDVI calculation given two input bands, as well as other information that can be retrieved from the
    original image.
    @param in_nir_band A GDAL band object representing the near-infrared image data.
    @type in_nir_band GDALRasterBand
    @param in_colour_band A GDAL band object representing the colour image data.
    @type: in_colour_band GDALRasterBand
    @param in_rows The number of rows in both input bands.
    @type: in_rows int
    @param in_cols The number of columns in both input bands.
    @type: in_cols int
    @param in_geotransform The geographic transformation to be applied to the output image.
    @type in_geotransform Tuple (as returned by GetGeoTransform())
    @param out_tiff Path to the desired output .tif file.
    @type: out_tiff String (should end in ".tif")
    @param data_type Data type of output image.  Valid values are gdal.UInt16 and gdal.Float32.  Default is
                      gdal.Float32
    @type data_type GDALDataType
    @return None
    """

    # Read the input bands as numpy arrays.
    np_nir = in_nir_band.ReadAsArray(0, 0, in_cols, in_rows)
    np_colour = in_colour_band.ReadAsArray(0, 0, in_cols, in_rows)

    # Convert the np arrays to 32-bit floating point to make sure division will occur properly.
    np_nir_as32 = np_nir.astype(np.float32)
    np_colour_as32 = np_colour.astype(np.float32)

    # Calculate the NDVI formula.
    numerator = subtract(np_nir_as32, np_colour_as32)
    denominator = add(np_nir_as32, np_colour_as32)
    result = divide(numerator, denominator)

    # Remove any out-of-bounds areas
    result[result == -0] = -99

    # Initialize a geotiff driver.
    geotiff = GetDriverByName('GTiff')

    # If the desired output is an int16, map the domain [-1,1] to [0,255], create an int16 geotiff with one band and
    # write the contents of the int16 NDVI calculation to it.  Otherwise, create a float32 geotiff with one band and
    # write the contents of the float32 NDVI calculation to it.
    if data_type == gdal.GDT_UInt16:
        ndvi_int8 = multiply((result + 1), (2**7 - 1))
        output = geotiff.Create(out_tiff, in_cols, in_rows, 1, gdal.GDT_Byte)
        output_band = output.GetRasterBand(1)
        output_band.SetNoDataValue(-99)
        output_band.WriteArray(ndvi_int8)
    elif data_type == gdal.GDT_Float32:
        output = geotiff.Create(out_tiff, in_cols, in_rows, 1, gdal.GDT_Float32)
        output_band = output.GetRasterBand(1)
        output_band.SetNoDataValue(-99)
        output_band.WriteArray(result)
    else:
        raise ValueError('Invalid output data type.  Valid types are gdal.UInt16 or gdal.Float32.')

    # Set the geographic transformation as the input.
    output.SetGeoTransform(in_geotransform)

    return None

# %%
# Seperate NIR and RED bands images into different folders and add path of parent directory
path = "/kaggle/input/msi-dji/MSI_DJI/" 
nir = sorted(glob(os.path.join(path, "NIR/*")))
red = sorted(glob(os.path.join(path, "RED/*")))
print(f"Total NIR images:  {len(nir)} - Total RED images: {len(red)}")
# Out:
# Total NIR images:  86 - Total RED images: 86

# %%
# set i to the number of images in dataset
for i in range(0, 86):
    # Open NIR image and get its only band.
    nir_tiff = Open(nir[i])
    nir_band = nir_tiff.GetRasterBand(1)

    # Open red image and get its only band.
    red_tiff = Open(red[i])
    red_band = red_tiff.GetRasterBand(1)

    # Get the rows and cols from one of the images (both should always be the same)
    rows, cols, geotransform = nir_tiff.RasterYSize, nir_tiff.RasterXSize, nir_tiff.GetGeoTransform()
    #     print(geotransform)

    # Set an output for a 16-bit unsigned integer (0-255)
    out_tiff_int16 = f"{i+1}"+r"_NDVI_INT16.tif"

    # Set the output for a 32-bit floating point (-1 to 1)
    out_tiff_float32 = f'{i+1}'+r'_NDVI_FLOAT32.tif'

    # Run the function for unsigned 16-bit integer
    ndvi(nir_band, red_band, rows, cols, geotransform, out_tiff_int16, gdal.GDT_UInt16)

    # Run the function for 32-bit floating point
    ndvi(nir_band, red_band, rows, cols, geotransform, out_tiff_float32, gdal.GDT_Float32)

    print('Generating NDVI ',i+1)
# Out:
# done  0
# done  1
# done  2
# done  3
# done  4
# done  5
# done  6
# done  7
# done  8
# done  9
# done  10
# done  11
# done  12
# done  13
# done  14
# done  15
# done  16
# done  17
# done  18
# done  19
# done  20
# done  21
# done  22
# done  23
# done  24
# done  25
# done  26
# done  27
# done  28
# done  29
# done  30
# done  31
# done  32
# done  33
# done  34
# done  35
# done  36
# done  37
# done  38
# done  39
# done  40
# done  41
# done  42
# done  43
# done  44
# done  45
# done  46
# done  47
# done  48
# done  49
# done  50
# done  51
# done  52
# done  53
# done  54
# done  55
# done  56
# done  57
# done  58
# done  59
# done  60
# done  61
# done  62
# done  63
# done  64
# done  65
# done  66
# done  67
# done  68
# done  69
# done  70
# done  71
# done  72
# done  73
# done  74
# done  75
# done  76
# done  77
# done  78
# done  79
# done  80
# done  81
# done  82
# done  83
# done  84
# done  85

# %%
# # delete file
# os.remove("/kaggle/working/NDVI_INT16.tif")

# %%
# !zip -r /kaggle/working/ndvi.zip /kaggle/working/
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/76_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/11_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/5_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/54_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/21_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/74_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/59_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/29_NDVI_FLOAT32.tif (deflated 15%)
#   adding: kaggle/working/30_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/40_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/1_NDVI_FLOAT32.tif (deflated 16%)
#   adding: kaggle/working/69_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/49_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/25_NDVI_FLOAT32.tif (deflated 16%)
#   adding: kaggle/working/63_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/45_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/71_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/6_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/62_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/2_NDVI_FLOAT32.tif (deflated 16%)
#   adding: kaggle/working/63_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/34_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/15_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/36_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/21_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/80_NDVI_FLOAT32.tif (deflated 15%)
#   adding: kaggle/working/65_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/72_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/13_NDVI_INT16.tif (deflated 24%)
#   adding: kaggle/working/39_NDVI_FLOAT32.tif (deflated 15%)
#   adding: kaggle/working/1_NDVI_INT16.tif (deflated 19%)
#   adding: kaggle/working/35_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/3_NDVI_FLOAT32.tif (deflated 15%)
#   adding: kaggle/working/34_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/20_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/42_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/4_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/57_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/85_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/25_NDVI_INT16.tif (deflated 23%)
#   adding: kaggle/working/35_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/23_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/86_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/76_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/7_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/56_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/15_NDVI_INT16.tif (deflated 18%)
#   adding: kaggle/working/31_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/49_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/43_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/51_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/64_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/24_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/41_NDVI_INT16.tif (deflated 18%)
#   adding: kaggle/working/54_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/19_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/37_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/30_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/47_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/83_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/38_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/85_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/82_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/82_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/10_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/62_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/9_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/79_NDVI_FLOAT32.tif (deflated 15%)
#   adding: kaggle/working/61_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/40_NDVI_INT16.tif (deflated 18%)
#   adding: kaggle/working/32_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/72_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/51_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/67_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/19_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/26_NDVI_FLOAT32.tif (deflated 18%)
#   adding: kaggle/working/33_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/65_NDVI_FLOAT32.tif (deflated 15%)
#   adding: kaggle/working/64_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/12_NDVI_FLOAT32.tif (deflated 16%)
#   adding: kaggle/working/14_NDVI_FLOAT32.tif (deflated 18%)
#   adding: kaggle/working/44_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/2_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/31_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/68_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/10_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/41_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/57_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/29_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/86_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/11_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/23_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/78_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/70_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/77_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/50_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/74_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/46_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/53_NDVI_INT16.tif (deflated 24%)
#   adding: kaggle/working/43_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/20_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/81_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/33_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/24_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/16_NDVI_INT16.tif (deflated 19%)
#   adding: kaggle/working/55_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/47_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/69_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/59_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/28_NDVI_FLOAT32.tif (deflated 17%)
#   adding: kaggle/working/55_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/37_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/60_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/38_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/48_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/68_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/16_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/36_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/45_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/81_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/77_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/7_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/58_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/58_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/73_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/9_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/79_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/71_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/70_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/28_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/75_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/13_NDVI_FLOAT32.tif (deflated 18%)
#   adding: kaggle/working/39_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/32_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/22_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/61_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/67_NDVI_INT16.tif (deflated 17%)
#   adding: kaggle/working/27_NDVI_FLOAT32.tif (deflated 16%)
#   adding: kaggle/working/26_NDVI_INT16.tif (deflated 23%)
#   adding: kaggle/working/6_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/17_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/48_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/17_NDVI_INT16.tif (deflated 19%)
#   adding: kaggle/working/66_NDVI_INT16.tif (deflated 17%)
#   adding: kaggle/working/18_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/56_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/52_NDVI_FLOAT32.tif (deflated 18%)
#   adding: kaggle/working/83_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/8_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/4_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/53_NDVI_FLOAT32.tif (deflated 18%)
#   adding: kaggle/working/78_NDVI_FLOAT32.tif (deflated 15%)
#   adding: kaggle/working/52_NDVI_INT16.tif (deflated 23%)
#   adding: kaggle/working/84_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/27_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/8_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/46_NDVI_INT16.tif (deflated 22%)
#   adding: kaggle/working/5_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/12_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/66_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/80_NDVI_INT16.tif (deflated 20%)
#   adding: kaggle/working/50_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/75_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/3_NDVI_INT16.tif (deflated 19%)
#   adding: kaggle/working/60_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/42_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/73_NDVI_INT16.tif (deflated 21%)
#   adding: kaggle/working/84_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/18_NDVI_FLOAT32.tif (deflated 13%)
#   adding: kaggle/working/44_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/22_NDVI_FLOAT32.tif (deflated 14%)
#   adding: kaggle/working/14_NDVI_INT16.tif (deflated 24%)
